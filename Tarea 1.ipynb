# %% [markdown]
# ### Ejercicio 1
# <div class="alert-success">
#
# ¿Dónde agregarías este código para ver en vivo los resultados de este último torneo?

# %%
import itertools
from random import choice
import pandas as pd

# Ejemplo de sociedad y estrategias
society = [{'id': 1, 'name': 'Alice', 'strategy': None, 'score': 0},
           {'id': 2, 'name': 'Bob', 'strategy': None, 'score': 0},
           {'id': 3, 'name': 'Jane', 'strategy': None, 'score': 0},
           {'id': 4, 'name': 'Zoe', 'strategy': None, 'score': 0}]

strategies = ['Rock', 'Paper', 'Scissors']

def payoff(strategy1, strategy2):
    if strategy1 == strategy2:
        return (0.5, 0.5)
    elif (strategy1 == 'Rock' and strategy2 == 'Scissors') or \
         (strategy1 == 'Scissors' and strategy2 == 'Paper') or \
         (strategy1 == 'Paper' and strategy2 == 'Rock'):
        return (1, 0)
    else:
        return (0, 1)

for aRound in range(20):  # esto sucederá 1000 veces, todos juegan contra todos
    # en cada ronda:
    for player1, player2 in itertools.combinations(society, 2):
        # cada uno elige estrategia
        player1['strategy'] = choice(strategies)
        player2['strategy'] = choice(strategies)
        
        # resultado de las estrategias elegidas
        print(player1['name'] + " chose " + player1['strategy'] + " - " + player2['name'] + " chose " + player2['strategy'])
        result = payoff(player1['strategy'], player2['strategy'])
        if result == (1, 0):
            print(player1['name'] + " won")
            player1['score'] += 1
        elif result == (0, 1):
            print(player2['name'] + " won")
            player2['score'] += 1
        else:
            print("TIE!")
            player1['score'] += 0.5
            player2['score'] += 0.5
# Out:
# Alice chose Rock - Bob chose Paper
# Bob won
# Alice chose Paper - Jane chose Rock
# Alice won
# Alice chose Rock - Zoe chose Scissors
# Alice won
# Bob chose Rock - Jane chose Rock
# TIE!
# Bob chose Rock - Zoe chose Scissors
# Bob won
# Jane chose Scissors - Zoe chose Scissors
# TIE!
# Alice chose Paper - Bob chose Paper
# TIE!
# Alice chose Scissors - Jane chose Paper
# Alice won
# Alice chose Paper - Zoe chose Rock
# Alice won
# Bob chose Scissors - Jane chose Rock
# Jane won
# Bob chose Rock - Zoe chose Paper
# Zoe won
# Jane chose Rock - Zoe chose Rock
# TIE!
# Alice chose Scissors - Bob chose Scissors
# TIE!
# Alice chose Paper - Jane chose Rock
# Alice won
# Alice chose Rock - Zoe chose Paper
# Zoe won
# Bob chose Scissors - Jane chose Scissors
# TIE!
# Bob chose Scissors - Zoe chose Rock
# Zoe won
# Jane chose Paper - Zoe chose Paper
# TIE!
# Alice chose Scissors - Bob chose Rock
# Bob won
# Alice chose Paper - Jane chose Rock
# Alice won
# Alice chose Paper - Zoe chose Rock
# Alice won
# Bob chose Scissors - Jane chose Scissors
# TIE!
# Bob chose Rock - Zoe chose Paper
# Zoe won
# Jane chose Scissors - Zoe chose Scissors
# TIE!
# Alice chose Paper - Bob chose Rock
# Alice won
# Alice chose Paper - Jane chose Scissors
# Jane won
# Alice chose Scissors - Zoe chose Scissors
# TIE!
# Bob chose Scissors - Jane chose Paper
# Bob won
# Bob chose Rock - Zoe chose Scissors
# Bob won
# Jane chose Rock - Zoe chose Rock
# TIE!
# Alice chose Scissors - Bob chose Paper
# Alice won
# Alice chose Scissors - Jane chose Paper
# Alice won
# Alice chose Scissors - Zoe chose Paper
# Alice won
# Bob chose Rock - Jane chose Paper
# Jane won
# Bob chose Paper - Zoe chose Scissors
# Zoe won
# Jane chose Scissors - Zoe chose Paper
# Jane won
# Alice chose Paper - Bob chose Scissors
# Bob won
# Alice chose Scissors - Jane chose Scissors
# TIE!
# Alice chose Rock - Zoe chose Scissors
# Alice won
# Bob chose Scissors - Jane chose Scissors
# TIE!
# Bob chose Paper - Zoe chose Paper
# TIE!
# Jane chose Scissors - Zoe chose Rock
# Zoe won
# Alice chose Scissors - Bob chose Paper
# Alice won
# Alice chose Paper - Jane chose Rock
# Alice won
# Alice chose Paper - Zoe chose Rock
# Alice won
# Bob chose Scissors - Jane chose Paper
# Bob won
# Bob chose Rock - Zoe chose Scissors
# Bob won
# Jane chose Paper - Zoe chose Scissors
# Zoe won
# Alice chose Scissors - Bob chose Scissors
# TIE!
# Alice chose Rock - Jane chose Rock
# TIE!
# Alice chose Rock - Zoe chose Rock
# TIE!
# Bob chose Rock - Jane chose Paper
# Jane won
# Bob chose Paper - Zoe chose Paper
# TIE!
# Jane chose Rock - Zoe chose Scissors
# Jane won
# Alice chose Scissors - Bob chose Scissors
# TIE!
# Alice chose Scissors - Jane chose Rock
# Jane won
# Alice chose Paper - Zoe chose Scissors
# Zoe won
# Bob chose Scissors - Jane chose Scissors
# TIE!
# Bob chose Scissors - Zoe chose Scissors
# TIE!
# Jane chose Scissors - Zoe chose Scissors
# TIE!
# Alice chose Paper - Bob chose Rock
# Alice won
# Alice chose Scissors - Jane chose Paper
# Alice won
# Alice chose Rock - Zoe chose Paper
# Zoe won
# Bob chose Scissors - Jane chose Scissors
# TIE!
# Bob chose Scissors - Zoe chose Rock
# Zoe won
# Jane chose Paper - Zoe chose Rock
# Jane won
# Alice chose Rock - Bob chose Scissors
# Alice won
# Alice chose Rock - Jane chose Rock
# TIE!
# Alice chose Paper - Zoe chose Rock
# Alice won
# Bob chose Rock - Jane chose Paper
# Jane won
# Bob chose Rock - Zoe chose Rock
# TIE!
# Jane chose Scissors - Zoe chose Paper
# Jane won
# Alice chose Scissors - Bob chose Scissors
# TIE!
# Alice chose Rock - Jane chose Rock
# TIE!
# Alice chose Scissors - Zoe chose Scissors
# TIE!
# Bob chose Rock - Jane chose Rock
# TIE!
# Bob chose Rock - Zoe chose Scissors
# Bob won
# Jane chose Scissors - Zoe chose Paper
# Jane won
# Alice chose Paper - Bob chose Rock
# Alice won
# Alice chose Rock - Jane chose Scissors
# Alice won
# Alice chose Rock - Zoe chose Rock
# TIE!
# Bob chose Paper - Jane chose Rock
# Bob won
# Bob chose Scissors - Zoe chose Scissors
# TIE!
# Jane chose Rock - Zoe chose Scissors
# Jane won
# Alice chose Scissors - Bob chose Scissors
# TIE!
# Alice chose Scissors - Jane chose Paper
# Alice won
# Alice chose Scissors - Zoe chose Rock
# Zoe won
# Bob chose Rock - Jane chose Scissors
# Bob won
# Bob chose Rock - Zoe chose Scissors
# Bob won
# Jane chose Rock - Zoe chose Scissors
# Jane won
# Alice chose Paper - Bob chose Paper
# TIE!
# Alice chose Scissors - Jane chose Scissors
# TIE!
# Alice chose Rock - Zoe chose Rock
# TIE!
# Bob chose Paper - Jane chose Paper
# TIE!
# Bob chose Rock - Zoe chose Paper
# Zoe won
# Jane chose Paper - Zoe chose Scissors
# Zoe won
# Alice chose Paper - Bob chose Rock
# Alice won
# Alice chose Paper - Jane chose Paper
# TIE!
# Alice chose Scissors - Zoe chose Paper
# Alice won
# Bob chose Paper - Jane chose Rock
# Bob won
# Bob chose Scissors - Zoe chose Rock
# Zoe won
# Jane chose Scissors - Zoe chose Paper
# Jane won
# Alice chose Scissors - Bob chose Paper
# Alice won
# Alice chose Paper - Jane chose Rock
# Alice won
# Alice chose Scissors - Zoe chose Scissors
# TIE!
# Bob chose Rock - Jane chose Scissors
# Bob won
# Bob chose Paper - Zoe chose Paper
# TIE!
# Jane chose Paper - Zoe chose Scissors
# Zoe won
# Alice chose Paper - Bob chose Paper
# TIE!
# Alice chose Paper - Jane chose Scissors
# Jane won
# Alice chose Paper - Zoe chose Scissors
# Zoe won
# Bob chose Rock - Jane chose Scissors
# Bob won
# Bob chose Scissors - Zoe chose Paper
# Bob won
# Jane chose Rock - Zoe chose Rock
# TIE!
# Alice chose Scissors - Bob chose Paper
# Alice won
# Alice chose Paper - Jane chose Rock
# Alice won
# Alice chose Paper - Zoe chose Rock
# Alice won
# Bob chose Paper - Jane chose Scissors
# Jane won
# Bob chose Rock - Zoe chose Rock
# TIE!
# Jane chose Paper - Zoe chose Scissors
# Zoe won

# %%
# final situation
society
# Out:
# [{'id': 1, 'name': 'Alice', 'strategy': 'Scissors', 'score': 31.0},
#  {'id': 2, 'name': 'Bob', 'strategy': 'Rock', 'score': 30.0},
#  {'id': 3, 'name': 'Jane', 'strategy': 'Rock', 'score': 32.0},
#  {'id': 4, 'name': 'Zoe', 'strategy': 'Scissors', 'score': 27.0}]

# %%
# as a data frame
socialResults=pd.DataFrame(society)
socialResults
# Out:
#    id   name  strategy  score
# 0   1  Alice  Scissors   31.0
# 1   2    Bob      Rock   30.0
# 2   3   Jane      Rock   32.0
# 3   4    Zoe  Scissors   27.0

# %%
winnerScore=socialResults.score.max()

#social outcome
socialResults[socialResults.score==winnerScore]
# Out:
#    id  name strategy  score
# 2   3  Jane     Rock   32.0
